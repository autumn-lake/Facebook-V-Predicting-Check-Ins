# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import time
# %matplotlib inline

# %%
#ftypes_train = dict(x=np.float32, y=np.float32, time=np.int32, place_id=np.int64)
ftypes_X = dict(x=np.float32, y=np.float32, time=np.int32)
ftypes_Y = dict(place_id=np.int64)
X = pd.read_csv("maha_train.csv", usecols=['x','y','time'], dtype=ftypes_X)
Y = pd.read_csv('maha_train.csv', usecols=['place_id'], dtype=ftypes_Y)

X_train = X[0:26206218]
Y_train = Y[0:26206218]

X_val = X[26206218:]
Y_val = Y[26206218:]

cova = X_train.cov()

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3, n_jobs=-1, algorithm='brute')

# %%
neigh.fit(X_train, Y_train)
# Out:
# /home/ds/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if __name__ == '__main__':
# KNeighborsClassifier(algorithm='brute', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
neigh.predict_proba(X_val)
# Out:
# /home/ds/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /home/ds/anaconda2/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# ---------------------------------------------------------------------------
# JoblibMemoryError                         Traceback (most recent call last)
# <ipython-input-5-080b7d73137f> in <module>()
# ----> 1 neigh.predict_proba(X_val)
#
# ...
